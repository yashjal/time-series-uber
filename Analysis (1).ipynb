# %%
import pandas as pd

# %%
df = pd.read_csv('manhattan_set.csv',header=None,index_col=None)
# Out:
# /Users/preetgandhi95/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    0       1                    2       3      4          5                6  \
# 0  1  B02617  2015-05-17 09:50:00  B02617  141.0  Manhattan  Lenox Hill West
# 1  2  B02617  2015-05-17 09:53:00  B02617  141.0  Manhattan  Lenox Hill West
# 2  3  B02617  2015-05-17 10:00:00  B02617  141.0  Manhattan  Lenox Hill West
# 3  4  B02617  2015-05-17 10:00:00  B02617  141.0  Manhattan  Lenox Hill West
# 4  5  B02617  2015-05-17 10:03:00  B00272  141.0  Manhattan  Lenox Hill West
#
#               7
# 0  1.431871e+09
# 1  1.431871e+09
# 2  1.431871e+09
# 3  1.431871e+09
# 4  1.431871e+09

# %%
len(df)
# Out:
# 10375608

# %%
 df[df[3].isnull()]
# Out:
#                                                           0             1  \
# 29                                                       30        B02598
# 91                                                       92        B02764
# 260                                                     261        B02764
# 373                                                     374        B02764
# 436                                                     437        B02764
# 529                                                     530        B02598
# 560                                                     561        B02598
# 662                                                     663        B02682
# 674                                                     675        B02682
# 840                                                     841        B02598
# 1263                                                   1264        B02598
# 1286                                                   1287        B02598
# ...

# %%
t = df[df[7].isnull()]

# %%
t
# Out:
#                                                           0             1  \
# 10375596  14270374,B02764,2015-05-15 17:38:00,B02764,105...  1431725880.0
# 10375597  14270375,B02764,2015-01-17 11:30:49,B02764,105...  1421512249.0
# 10375598  14270376,B02617,2015-06-04 20:55:00,B02617,105...  1433465700.0
# 10375599  14270377,B02598,2015-03-03 14:55:00,B02598,105...  1425412500.0
# 10375600  14270378,B02682,2015-05-28 20:39:00,B02682,105...  1432859940.0
# 10375601  14270379,B02512,2015-01-28 17:10:23,B02764,105...  1422483023.0
# 10375602  14270380,B02617,2015-01-28 10:44:35,B02764,105...  1422459875.0
# 10375603  14270381,B02682,2015-05-06 01:09:00,B02682,105...  1430888940.0
# 10375604  14270382,B02682,2015-02-02 14:00:45,B02682,105...  1422903645.0
# 10375605  14270383,B02765,2015-02-25 16:05:31,B00412,105...  1424898331.0
# 10375606  14270384,B02764,2015-02-21 15:24:41,B02764,105...  1424550281.0
# 10375607  14270385,B02764,2015-02-17 12:27:37,B02764,105...  1424194057.0
#
# ...

# %%
len(t)
# Out:
# 12

# %%
a =list(t[0])

# %%
a[0].split(',')
# Out:
# ['14270374',
#  'B02764',
#  '2015-05-15 17:38:00',
#  'B02764',
#  '105',
#  'Manhattan',
#  'Governors Island/Ellis Island/Liberty Island']

# %%
b =[]
for i in range(0,len(a)):
    b.append(a[i].split(','))

# %%
b[0]
# Out:
# ['14270374',
#  'B02764',
#  '2015-05-15 17:38:00',
#  'B02764',
#  '105',
#  'Manhattan',
#  'Governors Island/Ellis Island/Liberty Island']

# %%
c= pd.DataFrame(b)

# %%
tym = list(t[1])

# %%
tym = [int(float(i)) for i in tym]

# %%
c[7]=tym

# %%
c
# Out:
#            0       1                    2       3    4          5  \
# 0   14270374  B02764  2015-05-15 17:38:00  B02764  105  Manhattan
# 1   14270375  B02764  2015-01-17 11:30:49  B02764  105  Manhattan
# 2   14270376  B02617  2015-06-04 20:55:00  B02617  105  Manhattan
# 3   14270377  B02598  2015-03-03 14:55:00  B02598  105  Manhattan
# 4   14270378  B02682  2015-05-28 20:39:00  B02682  105  Manhattan
# 5   14270379  B02512  2015-01-28 17:10:23  B02764  105  Manhattan
# 6   14270380  B02617  2015-01-28 10:44:35  B02764  105  Manhattan
# 7   14270381  B02682  2015-05-06 01:09:00  B02682  105  Manhattan
# 8   14270382  B02682  2015-02-02 14:00:45  B02682  105  Manhattan
# 9   14270383  B02765  2015-02-25 16:05:31  B00412  105  Manhattan
# 10  14270384  B02764  2015-02-21 15:24:41  B02764  105  Manhattan
# 11  14270385  B02764  2015-02-17 12:27:37  B02764  105  Manhattan
#
#                                                6           7
# ...

# %%
 df[df[7].notnull()]
# Out:
#                  0       1                    2       3      4          5  \
# 0                1  B02617  2015-05-17 09:50:00  B02617  141.0  Manhattan
# 1                2  B02617  2015-05-17 09:53:00  B02617  141.0  Manhattan
# 2                3  B02617  2015-05-17 10:00:00  B02617  141.0  Manhattan
# 3                4  B02617  2015-05-17 10:00:00  B02617  141.0  Manhattan
# 4                5  B02617  2015-05-17 10:03:00  B00272  141.0  Manhattan
# 5                6  B02617  2015-05-17 10:04:00  B02617  141.0  Manhattan
# 6                7  B02617  2015-05-17 10:10:00  B02617  141.0  Manhattan
# 7                8  B02617  2015-05-17 10:17:00  B02617  141.0  Manhattan
# 8                9  B02617  2015-05-17 10:23:00  B02617  141.0  Manhattan
# 9               10  B02617  2015-05-17 10:33:00  B02764  141.0  Manhattan
# 10              11  B02598  2015-01-18 15:15:39  B02598  141.0  Manhattan
# 11              12  B02598  2015-01-18 00:37:16  B02774  141.0  Manhattan
# ...

# %%
c = c.append( df[df[7].notnull()])

# %%
c = c.sort_values(7)

# %%
c[7]=c[7].astype(int)

# %%
c
# Out:
#                  0       1                    2       3    4          5  \
# 8958176   11358149  B02598  2015-01-01 00:00:05  B02598  144  Manhattan
# 7257735    8140124  B02682  2015-01-01 00:00:08  B02682  113  Manhattan
# 3465860    3967546  B02682  2015-01-01 00:00:11  B02617  234  Manhattan
# 9622956   12371033  B02764  2015-01-01 00:00:13  B02764  232  Manhattan
# 467271      640525  B02617  2015-01-01 00:00:14  B02617   90  Manhattan
# 1228278    1641843  B02764  2015-01-01 00:00:25     NaN  229  Manhattan
# 5696891    6290111  B02764  2015-01-01 00:00:27  B02764  231  Manhattan
# 7360251    8242640  B02764  2015-01-01 00:00:28  B02764   68  Manhattan
# 103277      103278  B02764  2015-01-01 00:00:29  B00789  141  Manhattan
# 8667239   11008076  B02682  2015-01-01 00:00:35  B02682    4  Manhattan
# 1185311    1598876  B02764  2015-01-01 00:00:39  B02764  229  Manhattan
# 6647115    7529504  B02764  2015-01-01 00:00:41  B02764  148  Manhattan
# ...

# %%
start = c.iloc[0][7]
end = c.iloc[-1][7]

# %%
start
# Out:
# 1420088405

# %%
end
# Out:
# 1435723140

# %%
from datetime import datetime
s = datetime.fromtimestamp(start)
e = datetime.fromtimestamp(end)

# %%
s
# Out:
# datetime.datetime(2015, 1, 1, 0, 0, 5)

# %%
e
# Out:
# datetime.datetime(2015, 6, 30, 23, 59)

# %%
sh = int(s.strftime('%H'))
sm = int(s.strftime('%M'))
eh = int(e.strftime('%H'))
em = int(e.strftime('%M'))
flag = 0

# %%
if sm <30:
    sm=0
elif sm>=30:
    sm=30

# %%
import datetime
new_s=datetime.datetime(s.year, s.month, s.day, s.hour, sm)
print(new_s)
# Out:
# 2015-01-01 00:00:00

# %%
import datetime
round_mins = 30
mins = e.minute - (e.minute % round_mins)
new_e=datetime.datetime(e.year, e.month, e.day, e.hour, mins) + datetime.timedelta(minutes=round_mins)
print(new_e)
# Out:
# 2015-07-01 00:00:00

# %%
s =int(new_s.timestamp())
e =int(new_e.timestamp())

# %%
s
# Out:
# 1420088400

# %%
e
# Out:
# 1435723200

# %%
temp = c[:2000].copy()

# %%
def bucketify(row):
    curr_time = row[7]
    start_time = s
    return (curr_time - start_time) // 1800

# %%
c
# Out:
#                  0       1                    2       3    4          5  \
# 8958176   11358149  B02598  2015-01-01 00:00:05  B02598  144  Manhattan
# 7257735    8140124  B02682  2015-01-01 00:00:08  B02682  113  Manhattan
# 3465860    3967546  B02682  2015-01-01 00:00:11  B02617  234  Manhattan
# 9622956   12371033  B02764  2015-01-01 00:00:13  B02764  232  Manhattan
# 467271      640525  B02617  2015-01-01 00:00:14  B02617   90  Manhattan
# 1228278    1641843  B02764  2015-01-01 00:00:25     NaN  229  Manhattan
# 5696891    6290111  B02764  2015-01-01 00:00:27  B02764  231  Manhattan
# 7360251    8242640  B02764  2015-01-01 00:00:28  B02764   68  Manhattan
# 103277      103278  B02764  2015-01-01 00:00:29  B00789  141  Manhattan
# 8667239   11008076  B02682  2015-01-01 00:00:35  B02682    4  Manhattan
# 1185311    1598876  B02764  2015-01-01 00:00:39  B02764  229  Manhattan
# 6647115    7529504  B02764  2015-01-01 00:00:41  B02764  148  Manhattan
# ...

# %%
c[8] = c.apply(lambda row: bucketify(row), axis=1)

# %%
c
# Out:
#                  0       1                    2       3    4          5  \
# 8958176   11358149  B02598  2015-01-01 00:00:05  B02598  144  Manhattan
# 7257735    8140124  B02682  2015-01-01 00:00:08  B02682  113  Manhattan
# 3465860    3967546  B02682  2015-01-01 00:00:11  B02617  234  Manhattan
# 9622956   12371033  B02764  2015-01-01 00:00:13  B02764  232  Manhattan
# 467271      640525  B02617  2015-01-01 00:00:14  B02617   90  Manhattan
# 1228278    1641843  B02764  2015-01-01 00:00:25     NaN  229  Manhattan
# 5696891    6290111  B02764  2015-01-01 00:00:27  B02764  231  Manhattan
# 7360251    8242640  B02764  2015-01-01 00:00:28  B02764   68  Manhattan
# 103277      103278  B02764  2015-01-01 00:00:29  B00789  141  Manhattan
# 8667239   11008076  B02682  2015-01-01 00:00:35  B02682    4  Manhattan
# 1185311    1598876  B02764  2015-01-01 00:00:39  B02764  229  Manhattan
# 6647115    7529504  B02764  2015-01-01 00:00:41  B02764  148  Manhattan
# ...

# %%
c[8] = c[8]+1

# %%
c
# Out:
#                  0       1                    2       3    4          5  \
# 8958176   11358149  B02598  2015-01-01 00:00:05  B02598  144  Manhattan
# 7257735    8140124  B02682  2015-01-01 00:00:08  B02682  113  Manhattan
# 3465860    3967546  B02682  2015-01-01 00:00:11  B02617  234  Manhattan
# 9622956   12371033  B02764  2015-01-01 00:00:13  B02764  232  Manhattan
# 467271      640525  B02617  2015-01-01 00:00:14  B02617   90  Manhattan
# 1228278    1641843  B02764  2015-01-01 00:00:25     NaN  229  Manhattan
# 5696891    6290111  B02764  2015-01-01 00:00:27  B02764  231  Manhattan
# 7360251    8242640  B02764  2015-01-01 00:00:28  B02764   68  Manhattan
# 103277      103278  B02764  2015-01-01 00:00:29  B00789  141  Manhattan
# 8667239   11008076  B02682  2015-01-01 00:00:35  B02682    4  Manhattan
# 1185311    1598876  B02764  2015-01-01 00:00:39  B02764  229  Manhattan
# 6647115    7529504  B02764  2015-01-01 00:00:41  B02764  148  Manhattan
# ...

# %%
c.to_csv('mod_manhattan_set.csv')

# %%
from dateutil.parser import parse

def is_date(string):
    try: 
        parse(string)
        return True
    except ValueError:
        return False
