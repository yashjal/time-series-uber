# %%
import pandas as pd

df1 = pd.read_csv('uber-raw-data-apr14.csv')
df2 = pd.read_csv('uber-raw-data-may14.csv')
df3 = pd.read_csv('uber-raw-data-jun14.csv')
df4 = pd.read_csv('uber-raw-data-jul14.csv')
df5 = pd.read_csv('uber-raw-data-aug14.csv')
df6 = pd.read_csv('uber-raw-data-sep14.csv')
dfe = pd.concat([df1,df2,df3,df4,df5,df6])
dfe
# Out:
#                   Date/Time      Lat      Lon    Base
# 0          4/1/2014 0:11:00  40.7690 -73.9549  B02512
# 1          4/1/2014 0:17:00  40.7267 -74.0345  B02512
# 2          4/1/2014 0:21:00  40.7316 -73.9873  B02512
# 3          4/1/2014 0:28:00  40.7588 -73.9776  B02512
# 4          4/1/2014 0:33:00  40.7594 -73.9722  B02512
# 5          4/1/2014 0:33:00  40.7383 -74.0403  B02512
# 6          4/1/2014 0:39:00  40.7223 -73.9887  B02512
# 7          4/1/2014 0:45:00  40.7620 -73.9790  B02512
# 8          4/1/2014 0:55:00  40.7524 -73.9960  B02512
# 9          4/1/2014 1:01:00  40.7575 -73.9846  B02512
# 10         4/1/2014 1:19:00  40.7256 -73.9869  B02512
# 11         4/1/2014 1:48:00  40.7591 -73.9684  B02512
# 12         4/1/2014 1:49:00  40.7271 -73.9803  B02512
# 13         4/1/2014 2:11:00  40.6463 -73.7896  B02512
# 14         4/1/2014 2:25:00  40.7564 -73.9167  B02512
# 15         4/1/2014 2:31:00  40.7666 -73.9531  B02512
# ...

# %%
import os
os.environ["MAPBOX_ACCESS_TOKEN"] = "pk.eyJ1IjoieWFzaGphbDI2NTMiLCJhIjoiY2pmenVsanRiMTM4cDJxdGx1NmV3Mnh6diJ9.Pkiacl31hESfIZ_YrNPbtA"

from mapbox import Geocoder

geocoder = Geocoder()

geocoder.session.params['access_token'] == os.environ['MAPBOX_ACCESS_TOKEN']

response = geocoder.reverse(lon=-73.9496, lat=40.7140)
response.status_code
features = response.geojson()['features']
features[1]['place_name']
# Out:
# 'Williamsburg, Brooklyn, New York, New York 11211, United States'

# %%
dfe['Loc'] = ''
dfe.set_value(0, 'Loc', 'ab')
dfe.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#           Date/Time      Lat      Lon    Base Loc
# 0  4/1/2014 0:11:00  40.7690 -73.9549  B02512  ab
# 1  4/1/2014 0:17:00  40.7267 -74.0345  B02512
# 2  4/1/2014 0:21:00  40.7316 -73.9873  B02512
# 3  4/1/2014 0:28:00  40.7588 -73.9776  B02512
# 4  4/1/2014 0:33:00  40.7594 -73.9722  B02512

# %%
for index, row in dfe.iterrows():
    long = row['Lon']
    latt = row['Lat']
    response = geocoder.reverse(lon=long, lat=latt)
    response.status_code
    features = response.geojson()['features']
    dfe.set_value(index, 'Loc', features[1]['place_name'])
    if index >= 599:
        break
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys

# %%
dfe.head()
# Out:
#           Date/Time      Lat      Lon    Base  \
# 0  4/1/2014 0:11:00  40.7690 -73.9549  B02512
# 1  4/1/2014 0:17:00  40.7267 -74.0345  B02512
# 2  4/1/2014 0:21:00  40.7316 -73.9873  B02512
# 3  4/1/2014 0:28:00  40.7588 -73.9776  B02512
# 4  4/1/2014 0:33:00  40.7594 -73.9722  B02512
#
#                                                  Loc
# 0  Upper East Side, Manhattan, New York, New York...
# 1  The Waterfront, Jersey City, New Jersey 07310,...
# 2  East Village, Manhattan, New York, New York 10...
# 3  Midtown, Manhattan, New York, New York 10111, ...
# 4  Midtown, Manhattan, New York, New York 10022, ...

# %%
dfe.tail()
# Out:
#                   Date/Time      Lat      Lon    Base Loc
# 1028131  9/30/2014 22:57:00  40.7668 -73.9845  B02764
# 1028132  9/30/2014 22:57:00  40.6911 -74.1773  B02764
# 1028133  9/30/2014 22:58:00  40.8519 -73.9319  B02764
# 1028134  9/30/2014 22:58:00  40.7081 -74.0066  B02764
# 1028135  9/30/2014 22:58:00  40.7140 -73.9496  B02764

# %%
dfe.to_csv('data2.csv')
